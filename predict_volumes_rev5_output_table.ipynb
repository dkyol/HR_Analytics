# %%
import glob
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

#directory of reference tables 

empCube = 'C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Model_Development/Data/EmpCube/FACTDATA_MAR201?.TXT'
refData = 'C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Model_Development/Data/REF_Tables/*'

#accensions and seperations source files

accData = 'C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Model_Development/Data/ACC/ACCDATA_FY2011-2017.TXT'
sepData = 'C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Model_Development/Data/SEP/SEPDATA_FY2011-2017.TXT'


def load_emp_fact():

    '''Employment cube load'''

    df_total = pd.DataFrame()

    for name in glob.glob(empCube):


        df = pd.read_csv(name,dtype={ 'AGYSUB': str, 'LOC': str, 'AGELVL': str, 'EDLVL': str, 'GSEGRD': str, 'LOSLVL': str, 'OCC': str, 'PATCO': str,
       'PPGRD': str, 'SALLVL': str, 'STEMOCC': str, 'SUPERVIS': str, 'TOA': str, 'WORKSCH': str, 'WORKSTAT': str,
       'DATECODE': str, 'EMPLOYMENT': str, 'SALARY': str, 'LOS': float})    
        df_total = pd.concat([df_total, df])

    #clean salary col cast to integer
    df_total['SALARY'] = df_total['SALARY'].str.replace('$','')
    df_total['SALARY'] = df_total['SALARY'].str.replace(',','')

    df_total = df_total.dropna(axis = 0, how = 'any')

    df_total['SALARY'] = df_total['SALARY'].astype(int)
    
    df_total.drop(['EDLVL', 'EMPLOYMENT', 'STEMOCC', 'SUPERVIS', 'WORKSTAT'], axis = 1 ,inplace = True)
    
    #just 2018 data 
    df_2018 = df_total.loc[df_total['DATECODE'] == '201803']
    
    df_2018_date = df_2018.drop(['DATECODE'], axis =1)
    
    return df_2018_date


def load_acc_fact():

    '''Load accessions data'''

    print('Loading data...')

    df = pd.read_csv(accData, low_memory=False)

    df = df.dropna(axis = 0, how = 'any')

    df['SALARY'] = df['SALARY'].astype(int)
    
    return df    

def load_sep_fact():

    '''Load separations data'''

    df = pd.read_csv(sepData, low_memory=False)

    df = df.dropna(axis = 0, how = 'any')

    df['SALARY'] = df['SALARY'].astype(int)
    
    df = df[df['OCC'] != '****']

    df = df[df['TOA'] != '**']

    return df




def load_dim_table():

    '''load reference tables'''

    ref_list = []

    for name in glob.glob(refData):

        ref_list.append(pd.read_csv(name))

    return ref_list  



def join_func( df, df_other):

    df = df.merge(df_other)

    return df


def joins(df, data):

    '''indexing based on number and order of reference tables found in the directory '''

    dim = load_dim_table()

    acc = dim[0]
    age = dim[1]
    agency = dim[2]
    education = dim[4]
    date = dim[5]
    grade = dim[6][1:]
    location = dim[7]
    los = dim[8]
    occ = dim[9]
    patco = dim[10]
    paygroup = dim[11]
    salary = dim[12]
    separation = dim[13]
    stem = dim[14]
    supervisor = dim[15]  
    toa = dim[16]
    workstat = dim[17]
    worksch = dim[18]

    # load fact table 

    df_join = df

    '''reference tables joined to acc/sep fact tables'''  

    if (data == 'accessions'):

        df_join = join_func(df_join, acc)
        
        df_join = join_func(df_join, date)
        
        df_join = join_func(df_join, patco)
    
    elif(data =='separations'):

        df_join = join_func(df_join, separation)
        
        df_join = join_func(df_join, date)
        
        df_join = join_func(df_join, patco)
    
    else:
        
        pass

    df_join = join_func(df_join, age)

    df_join = join_func(df_join, agency)    

    df_join = join_func(df_join, location)

    df_join = join_func(df_join, los)

    df_join = join_func(df_join, paygroup)

    df_join = join_func(df_join, salary)

    df_join = join_func(df_join, toa)

    df_join = join_func(df_join, worksch)

    df_join = join_func(df_join, occ)

    return df_join



def join_dim_tables():   

    '''reduce star schema to table'''


    df_joins_acc = joins(load_acc_fact(), 'accessions')

    df_joins_sep = joins(load_sep_fact(), 'separations')


    return df_joins_acc, df_joins_sep  


def raw_data():
    
    acc, sep = join_dim_tables()

    rawData = pd.concat([acc, sep], axis = 0, sort = True)

    rawData['YEAR'] = rawData['EFDATE'].apply(lambda x : x//100)
    
    rawData['QTR'] = rawData['QTR'].astype(str)
    
    # two year data labels and data set

    Year_data = rawData.loc[(rawData['YEAR']>= 2015)]

    X = Year_data.loc[:,('AGELVLT', 'AGYSUBT', 'AGYT', 'AGYTYPT', 'LOCT',
       'LOCTYPT', 'LOS', 'LOSLVLT', 'OCCFAMT', 'PAYPLANT', 'PPGROUPT',
        'PPTYPT', 'SALARY', 'SALLVLT','TOAT', 'TOATYPT', 'WORKSCHT', 'WSTYPT')]


    rawDatalabel = Year_data.loc[:,('ACCT','SEPT')]

    rawDatalabel['ACCT'].update(rawDatalabel.pop('SEPT'))
    
    y_full = rawDatalabel['ACCT'] 
    
    binaryLabel = rawDatalabel['ACCT'].apply(lambda x: 1 if x =='Quit' else 0)

    df_binary = pd.DataFrame(binaryLabel)

    rawDatalabel['ACCT'] = rawDatalabel['ACCT'].apply(lambda x: 'QUIT' if x =='Quit' else 'notQuit')      

    df_label = pd.DataFrame(rawDatalabel['ACCT'] + Year_data['YEAR'].astype(str))

    def labeling(x):
        if x == 'QUIT2015':
            return 't+2'
        elif x == 'QUIT2016':
            return 't+1'
        elif x == 'QUIT2017':
            return 't'
        else:
            return 'Not_Quitting'

    y = df_label[0].apply(labeling)
    
    return X, y, df_binary, y_full
    

def dummies_func(X,y):
    
    X_encoded = pd.get_dummies(X)
    
    y_encoded = pd.get_dummies(y)
    
    return X_encoded, y_encoded

    


def correl(df,features):

    '''Join features with label data and produce correlation matrix'''

    print("Loading correlation matrix...")

    X = df

    df = X[features] 

    df = pd.concat([df,y], axis = 1)  

    df_dummy = pd.get_dummies(df)

    matrix = df_dummy.corr()

    fig, ax = plt.subplots(figsize=(20,20))         

    obj = sns.heatmap(matrix, linewidths=.1, xticklabels=True, yticklabels=True, ax=ax)

    plt.show(obj)

    return obj



def quit_correlation():
    
    a, b, c, d = raw_data()
    
    a_dummy = pd.get_dummies(a)
    
    c = c.rename(columns = {"ACCT": "Quit"})
    
    feature_list = list(a_dummy.columns)

    corr_dict =  {}

    c = c.rename(columns = {"ACCT": "Quit"})

    for feature in feature_list:

        c[feature] = a_dummy[feature]

        matrix = c.corr()

        feature_corr = matrix.iloc[0,1]

        corr_dict.update(({feature:feature_corr}))

        c.drop([feature], axis = 1, inplace = True)
        
    corr_table = pd.DataFrame.from_dict(data = corr_dict, orient = 'index')
    
    corr_table.sort_values(0, ascending = False, inplace = True)
        
    return corr_table

def corr_matrix():
    
    a, b, c, d = raw_data()
    
    rawXy = pd.concat([a, d], axis = 1)
    
    dummyXy = pd.get_dummies(rawXy)
    
    matrix = dummXy.corr()
    
    return matrix   


def model_matrix():
    
    #employment cube 
    
    cube = load_emp_fact()
    
    cube_all = joins(cube, 'none')
    
    cube_red = cube_all[['AGELVLT', 'AGYSUBT', 'AGYT', 'AGYTYPT', 'LOCT', 'LOCTYPT', 'LOS',
       'LOSLVLT', 'OCCFAMT', 'PAYPLANT', 'PPGROUPT', 'PPTYPT', 'SALARY',
       'SALLVLT', 'TOAT', 'TOATYPT', 'WORKSCHT', 'WSTYPT']]
    
    cube_d = pd.get_dummies(cube_red)
    
    #acc/separations confusion matrix 
    
    X, y, c, d = raw_data()

    Xd, yd  = dummies_func(X,y)
    
    # find common features for compatibility 
    
    common = list(set(Xd) & set(cube_d))
    
    Xd_common = Xd[common]
    
    cube_d_common = cube_d[common]   
    
    # confusion matrix 

    cols = yd.columns

    X_train, X_test, y_train, y_test = train_test_split(Xd_common, yd, test_size = .3, random_state = 305)

    model = DecisionTreeClassifier(random_state = 305)

    model.fit(X_train, y_train)

    y_predict_test = model.predict(X_test)

    conf_array = confusion_matrix(y_test.values.argmax(axis =1), y_predict_test.argmax(axis=1), labels = [0, 1, 2, 3])

    conf_df = pd.DataFrame(conf_array, index = cols, columns = cols)
    
    return Xd_common, yd, cube_d_common, model, conf_df


def pred_vols(cube_data):
    
    pred_vols = model.predict(cube_data)
    
    vols = pred_vols.argmax(axis = 1)
    
    df_vols = pd.DataFrame(vols)
    
    df_vols[0].value_counts()
    
    volume_preds = []
    
    for i in range(4):
        
        volume_preds.append(df_vols[0].value_counts()[i])

    volumes = pd.DataFrame(volume_preds, index = ['Not_quiting', '2018', '2019 ', '2020'], columns = ['Projected_quitters'])

    return volumes


def subfieldList(prefix):

    category_list = []

    for col in list(cube_d_common.columns):

        prefix = prefix

        pattern = prefix + '.+'

        startsWith = re.compile(pattern)

        result = startsWith.match(col)

        if result != None:

            category_list.append(result.group(0))

    return category_list  


def subfield_predsdf(subfield):
    
    df = cube_d_common[cube_d_common[subfield] == 1]
    
    return df 

def df_prediction_subfield(prefix, model):
    
    dictionary = {}

    sub_list = subfieldList(prefix)

    for sub in sub_list:

        df_sub = subfield_predsdf(sub)

        predictionsBy = model.predict(df_sub)

        #print(sub)

        #print(predictionsBy.shape)

        df_preds = pd.DataFrame(predictionsBy)

        df_sum = df_preds.sum(axis = 0)

        dictionary.update({sub:[predictionsBy.shape[0] ,df_sum[1], df_sum[2], df_sum[3]]})

    df_out = pd.DataFrame.from_dict(data = dictionary, orient = 'index', columns = ['Current Volume','quit (t)', 'quit (t+1)', 'quit (t+2)'])
    
    return df_out

# %%
Xd_common, yd, cube_d_common, model, conf_df = model_matrix()
# Out:
# Loading data...

# %%
cube_d_common.shape
# Out:
# (1257656, 841)

# %%
prefixList = ['AGELVLT', 'AGYSUBT', 'AGYT', 'AGYTYPT', 'LOCT', 'LOCTYPT', 'LOS',
       'LOSLVLT', 'OCCFAMT', 'PAYPLANT', 'PPGROUPT', 'PPTYPT', 'SALARY',
       'SALLVLT', 'TOAT', 'TOATYPT', 'WORKSCHT', 'WSTYPT']

df = pd.DataFrame([])

for pre in prefixList:
    
    print(pre)
    
    df = df.append(df_prediction_subfield(pre, model))
# Out:
# AGELVLT
# AGYSUBT
# AGYT
# AGYTYPT
# LOCT
# LOCTYPT
# LOS
# LOSLVLT
# OCCFAMT
# PAYPLANT
# PPGROUPT
# PPTYPT
# SALARY
# SALLVLT
# TOAT
# TOATYPT
# WORKSCHT
# WSTYPT

# %%
df
# Out:
#                                                    Current Volume  quit (t)  \
# AGELVLT_35-39                                              155708   19903.0
# AGELVLT_60-64                                              122592    2756.0
# AGELVLT_50-54                                              205068   16943.0
# AGELVLT_45-49                                              172833   17110.0
# AGELVLT_40-44                                              142216   16801.0
# AGELVLT_55-59                                              197498   10389.0
# AGELVLT_Less than 20                                          709     179.0
# AGELVLT_30-34                                              120752   15833.0
# AGELVLT_25-29                                               58497    9254.0
# AGELVLT_20-24                                               16376    3432.0
# AGELVLT_65 or more                                          65407    1771.0
# AGYSUBT_EP00-ENVIRONMENTAL PROTECTION AGENCY                13501     986.0
# AGYSUBT_IN01-OFFICE OF THE SECRETARY OF THE INT...           3364     106.0
# AGYSUBT_GX00-INTERNATIONAL BOUNDARY COMMISSION:...              7       1.0
# AGYSUBT_NV60-UNITED STATES FLEET FORCES COMMAND             13999    1532.0
# AGYSUBT_TRTG-OFFICE OF THE INSPECTOR GENERAL FO...            458      12.0
# AGYSUBT_AF1S-HEADQUARTERS, AIR FORCE SPACE COMMAND           5569     289.0
# AGYSUBT_NN51-GODDARD SPACE FLIGHT CENTER                     3115     290.0
# AGYSUBT_NV70-U.S. PACIFIC FLEET, COMMANDER IN C...           9922    1041.0
# AGYSUBT_HE13-OFFICE OF INSPECTOR GENERAL                     1031     174.0
# AGYSUBT_AM00-U.S. AGENCY FOR INTERNATIONAL DEVE...           1402      83.0
# AGYSUBT_VAPA-NATIONAL CEMETERY ADMINISTRATION                 886      81.0
# AGYSUBT_IN07-BUREAU OF RECLAMATION                           4222     219.0
# AGYSUBT_TD05-FEDERAL RAILROAD ADMINISTRATION                  892     104.0
# AGYSUBT_HUEE-ASSISTANT SECRETARY FOR FAIR HOUSI...            106       2.0
# AGYSUBT_VABK-OFFICE OF ENTERPRISE OPERATIONS                   17       0.0
# AGYSUBT_CM54-NATIONAL OCEANIC AND ATMOSPHERIC A...           4959     467.0
# AGYSUBT_EDEH-OFFICE OF SPECIAL EDUCATION AND RE...            180       6.0
# AGYSUBT_DD12-DEFENSE SECURITY SERVICE                         675      86.0
# AGYSUBT_ST00-DEPARTMENT OF STATE                            11156    1049.0
# ...                                                           ...       ...
# TOAT_30-Excepted Service - Schedule A                       40421    5581.0
# TOATYPT_Unspecified                                           279      42.0
# TOAT_38-Excepted Service - Other                           173404   22832.0
# TOAT_35-Excepted Service - Schedule D                        8343    1616.0
# TOAT_10-Competitive Service - Career                       828307   55655.0
# TOAT_**-Unspecified                                           299      42.0
# TOATYPT_Permanent                                         1197541  106728.0
# TOAT_45-Excepted Service - Schedule D                        1872     442.0
# TOAT_15-Competitive Service - Career-Conditional           146144   21002.0
# TOAT_42-Excepted Service - Schedule B                        1131     144.0
# TOAT_32-Excepted Service - Schedule B                         902      42.0
# TOAT_48-Excepted Service - Other                            19070    2027.0
# TOAT_44-Excepted Service - Schedule C                        1005     552.0
# TOAT_40-Excepted Service - Schedule A                       16170    1888.0
# TOATYPT_Non-permanent                                       59836    7601.0
# TOATYPT_Unspecified                                           279      42.0
# TOATYPT_Permanent                                         1197541  106728.0
# WORKSCHT_J - Intermittent Seasonal                           1470     264.0
# WORKSCHT_* - Unspecified                                        4       1.0
# WORKSCHT_G - Full-time Seasonal                             21276    3970.0
# WORKSCHT_B - Full-time Nonseasonal Baylor Pln                   4       0.0
# WORKSCHT_F - Full-time Nonseasonal                        1190705  104250.0
# WORKSCHT_R - Part-time On-call                                130       0.0
# WORKSCHT_P - Part-time Nonseasonal                          20658    3027.0
# WORKSCHT_Q - Part-time Seasonal                              2015     428.0
# WORKSCHT_S - Part-time Job Sharer Nonseasonal                 272      39.0
# WORKSCHT_I - Intermittent Nonseasonal                       21122    2392.0
# WSTYPT_Not Full-time                                        45667    6150.0
# WSTYPT_Unspecified                                              4       1.0
# WSTYPT_Full-time                                          1211985  108220.0
#
#                                                     quit (t+1)  quit (t+2)
# AGELVLT_35-39                                          22712.0     18034.0
# AGELVLT_60-64                                           3439.0      2890.0
# AGELVLT_50-54                                          19760.0     17383.0
# AGELVLT_45-49                                          19820.0     17148.0
# AGELVLT_40-44                                          18705.0     16411.0
# AGELVLT_55-59                                          12173.0     10355.0
# AGELVLT_Less than 20                                     125.0        77.0
# AGELVLT_30-34                                          20230.0     15886.0
# AGELVLT_25-29                                          10162.0      8554.0
# AGELVLT_20-24                                           3421.0      2088.0
# AGELVLT_65 or more                                      1700.0      1770.0
# AGYSUBT_EP00-ENVIRONMENTAL PROTECTION AGENCY             832.0      1083.0
# AGYSUBT_IN01-OFFICE OF THE SECRETARY OF THE INT...       181.0       197.0
# AGYSUBT_GX00-INTERNATIONAL BOUNDARY COMMISSION:...         1.0         0.0
# AGYSUBT_NV60-UNITED STATES FLEET FORCES COMMAND         1325.0       997.0
# AGYSUBT_TRTG-OFFICE OF THE INSPECTOR GENERAL FO...        39.0        28.0
# AGYSUBT_AF1S-HEADQUARTERS, AIR FORCE SPACE COMMAND       408.0       519.0
# AGYSUBT_NN51-GODDARD SPACE FLIGHT CENTER                 232.0       215.0
# AGYSUBT_NV70-U.S. PACIFIC FLEET, COMMANDER IN C...      1026.0      1101.0
# AGYSUBT_HE13-OFFICE OF INSPECTOR GENERAL                  82.0        56.0
# AGYSUBT_AM00-U.S. AGENCY FOR INTERNATIONAL DEVE...        83.0       104.0
# AGYSUBT_VAPA-NATIONAL CEMETERY ADMINISTRATION             68.0        33.0
# AGYSUBT_IN07-BUREAU OF RECLAMATION                       339.0       279.0
# AGYSUBT_TD05-FEDERAL RAILROAD ADMINISTRATION              57.0        91.0
# AGYSUBT_HUEE-ASSISTANT SECRETARY FOR FAIR HOUSI...         4.0         7.0
# AGYSUBT_VABK-OFFICE OF ENTERPRISE OPERATIONS               0.0         0.0
# AGYSUBT_CM54-NATIONAL OCEANIC AND ATMOSPHERIC A...       337.0       299.0
# AGYSUBT_EDEH-OFFICE OF SPECIAL EDUCATION AND RE...         2.0         4.0
# AGYSUBT_DD12-DEFENSE SECURITY SERVICE                     55.0        70.0
# AGYSUBT_ST00-DEPARTMENT OF STATE                         994.0       939.0
# ...                                                        ...         ...
# TOAT_30-Excepted Service - Schedule A                   5755.0      4648.0
# TOATYPT_Unspecified                                       47.0        51.0
# TOAT_38-Excepted Service - Other                       31563.0     24333.0
# TOAT_35-Excepted Service - Schedule D                   1624.0       887.0
# TOAT_10-Competitive Service - Career                   66661.0     60055.0
# TOAT_**-Unspecified                                       48.0        52.0
# TOATYPT_Permanent                                     126630.0    104919.0
# TOAT_45-Excepted Service - Schedule D                    209.0       234.0
# TOAT_15-Competitive Service - Career-Conditional       20944.0     14887.0
# TOAT_42-Excepted Service - Schedule B                    190.0       132.0
# TOAT_32-Excepted Service - Schedule B                     82.0       108.0
# TOAT_48-Excepted Service - Other                        1667.0      1734.0
# TOAT_44-Excepted Service - Schedule C                     52.0        75.0
# TOAT_40-Excepted Service - Schedule A                   1301.0      1998.0
# TOATYPT_Non-permanent                                   5570.0      5626.0
# TOATYPT_Unspecified                                       47.0        51.0
# TOATYPT_Permanent                                     126630.0    104919.0
# WORKSCHT_J - Intermittent Seasonal                       156.0       144.0
# WORKSCHT_* - Unspecified                                   0.0         0.0
# WORKSCHT_G - Full-time Seasonal                         3943.0      3499.0
# WORKSCHT_B - Full-time Nonseasonal Baylor Pln              2.0         1.0
# WORKSCHT_F - Full-time Nonseasonal                    120013.0    100128.0
# WORKSCHT_R - Part-time On-call                             0.0         1.0
# WORKSCHT_P - Part-time Nonseasonal                      4474.0      3777.0
# WORKSCHT_Q - Part-time Seasonal                          248.0       503.0
# WORKSCHT_S - Part-time Job Sharer Nonseasonal             42.0        35.0
# WORKSCHT_I - Intermittent Nonseasonal                   3369.0      2508.0
# WSTYPT_Not Full-time                                    8289.0      6968.0
# WSTYPT_Unspecified                                         0.0         0.0
# WSTYPT_Full-time                                      123958.0    103628.0
#
# [860 rows x 4 columns]

# %%
df.to_excel("volumes_by_type_withVols.xlsx")

# %%
df_vol.to_excel("volumes.xlsx")

# %%
heatmap_df.to_excel("heatmap.xlsx")

# %%
df_quit.to_excel("quit_dataframe.xlsx")

# %%
df.to_excel("confusion_matrix.xlsx")
